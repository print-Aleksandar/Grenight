# %% [markdown]
# ### Both sides are playing with random policy
# - First goal of this analytics is to decide number of maximum steps before truncation for training for 4x5 board.
#  - Second goal is to show if there is any bias towards specific color from domain and application.

# %%
import time
from collections import Counter
from environment.grenight_environment import GrenightEnvironment
from domain.configs import MAX_ALLOWED_STEPS_WITHOUT_PAWN_MOVE_OR_CAPTURING

# %%
MAX_MOVES_PER_EPISODES = [25, 40, 50, 60, 70, 80, 90, 100, 200, 500]

# %%
def play_random_game(env_arg: GrenightEnvironment,
                     current_max_moves_per_ep: int) -> tuple[str, int, dict]:

    env_arg.reset()
    done = False
    move_count = 0
    acting_player_is_white = True
    reward = 0.0
    info = None

    while not done and move_count < current_max_moves_per_ep:
        acting_player_is_white = env_arg.is_white_on_turn
        action = env_arg.sample()
        _, reward, done, info = env_arg.step(action)
        move_count += 1

    if not done:
        return "truncated", move_count, info
    if reward == 0.0:
        return "draw", move_count, info

    winner_is_white = acting_player_is_white if reward > 0 else not acting_player_is_white

    return ("white_win", move_count, info) if winner_is_white else ("black_win", move_count, info)

# %%
env = GrenightEnvironment()

for current_max_steps_per_ep in MAX_MOVES_PER_EPISODES:

    outcomes_counter = Counter()
    total_step_counts_per_outcome = Counter()
    draw_reasons = Counter()

    start_time = time.perf_counter()
    for _ in range(100):
        outcome, steps, game_info = play_random_game(env, current_max_steps_per_ep)
        outcomes_counter[outcome] += 1
        if outcome != "truncated":
            total_step_counts_per_outcome[outcome] += steps
        if game_info["draw_reason"] is not None:
            draw_reasons[game_info["draw_reason"]] += 1
    end_time = time.perf_counter()

    avg_step_counts_per_outcome = dict()
    for outcome, total_steps in total_step_counts_per_outcome.items():
        avg_step_counts_per_outcome[outcome] = total_steps / outcomes_counter[outcome]

    print(f"Outcomes in 100 games where max steps without pawn movement or capturing: {MAX_ALLOWED_STEPS_WITHOUT_PAWN_MOVE_OR_CAPTURING}\n"
          f"And total max steps per episode were {current_max_steps_per_ep}:\n"
          f"{outcomes_counter}\n"
          f"Average moves per outcome: \n{avg_step_counts_per_outcome}\n"
          f"Draw reasons: \n{draw_reasons}\n"
          f"Execution time: {end_time - start_time:.2f} seconds\n")
# Out:
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 25:
# Counter({'truncated': 91, 'black_win': 6, 'white_win': 3})
# Average moves per outcome:
# {'black_win': 13.0, 'white_win': 23.0}
# Draw reasons:
# Counter()
# Execution time: 11.72 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 40:
# Counter({'truncated': 69, 'black_win': 11, 'draw': 10, 'white_win': 10})
# Average moves per outcome:
# {'draw': 32.6, 'black_win': 21.09090909090909, 'white_win': 21.2}
# Draw reasons:
# Counter({'insufficient_material': 2, 'threefold_repetition': 1, 'max_steps_without_progress': 1})
# Execution time: 14.27 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 50:
# Counter({'truncated': 54, 'draw': 27, 'white_win': 14, 'black_win': 5})
# Average moves per outcome:
# {'draw': 36.0, 'white_win': 19.571428571428573, 'black_win': 24.8}
# Draw reasons:
# Counter({'insufficient_material': 5, 'max_steps_without_progress': 2})
# Execution time: 16.38 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 60:
# Counter({'draw': 41, 'truncated': 37, 'white_win': 13, 'black_win': 9})
# Average moves per outcome:
# {'draw': 46.853658536585364, 'white_win': 27.615384615384617, 'black_win': 18.444444444444443}
# Draw reasons:
# Counter({'insufficient_material': 15, 'max_steps_without_progress': 10, 'threefold_repetition': 3})
# Execution time: 18.10 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 70:
# Counter({'draw': 60, 'truncated': 18, 'white_win': 12, 'black_win': 10})
# Average moves per outcome:
# {'black_win': 22.4, 'draw': 50.45, 'white_win': 24.333333333333332}
# Draw reasons:
# Counter({'insufficient_material': 22, 'max_steps_without_progress': 19, 'threefold_repetition': 1})
# Execution time: 17.52 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 80:
# Counter({'draw': 64, 'white_win': 16, 'black_win': 12, 'truncated': 8})
# Average moves per outcome:
# {'draw': 54.75, 'black_win': 20.5, 'white_win': 26.625}
# Draw reasons:
# Counter({'insufficient_material': 22, 'max_steps_without_progress': 19, 'threefold_repetition': 4})
# Execution time: 17.52 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 90:
# Counter({'draw': 80, 'white_win': 11, 'black_win': 6, 'truncated': 3})
# Average moves per outcome:
# {'white_win': 22.454545454545453, 'draw': 56.8375, 'black_win': 25.666666666666668}
# Draw reasons:
# Counter({'insufficient_material': 29, 'max_steps_without_progress': 28, 'threefold_repetition': 3})
# Execution time: 18.21 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 100:
# Counter({'draw': 72, 'white_win': 15, 'black_win': 12, 'truncated': 1})
# Average moves per outcome:
# {'draw': 58.80555555555556, 'white_win': 27.133333333333333, 'black_win': 32.666666666666664}
# Draw reasons:
# Counter({'max_steps_without_progress': 28, 'insufficient_material': 26})
# Execution time: 18.67 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 200:
# Counter({'draw': 68, 'black_win': 16, 'white_win': 16})
# Average moves per outcome:
# {'draw': 56.76470588235294, 'black_win': 29.375, 'white_win': 26.8125}
# Draw reasons:
# Counter({'insufficient_material': 26, 'max_steps_without_progress': 24, 'threefold_repetition': 1})
# Execution time: 17.14 seconds
#
# Outcomes in 100 games where max steps without pawn movement or capturing: 20
# And total max steps per episode were 500:
# Counter({'draw': 73, 'white_win': 15, 'black_win': 12})
# Average moves per outcome:
# {'black_win': 27.666666666666668, 'draw': 63.06849315068493, 'white_win': 28.2}
# Draw reasons:
# Counter({'insufficient_material': 32, 'max_steps_without_progress': 28, 'threefold_repetition': 1})
# Execution time: 18.78 seconds

# %% [markdown]
# #### Conclusion
# - From this analytics for 4x5 board I am deciding that 200 is correct number for maximum steps before truncation in training.
# - Out of this few hundred games total difference of winner color is not drastic. There is no correlation between maximum steps before truncation and which color had more wins. There is no correlation between average steps to win and which color had more wins over the number of maximum steps before truncation.
